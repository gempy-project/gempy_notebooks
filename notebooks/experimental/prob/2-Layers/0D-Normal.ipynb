# %%
 # These two lines are necessary only if GemPy is not installed
import sys, os
sys.path.append("../../../..")
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=cpu"

# Importing GemPy
import gempy as gp

# Embedding matplotlib figures in the notebooks
# %matplotlib notebook

# Importing auxiliary libraries
import numpy as np
import matplotlib.pyplot as plt
import pymc3 as pm
import arviz as az

# %% [markdown]
# ## Model definition

# %%
with pm.Model() as model:
    mu = pm.Normal('$\mu$', 10, 5)
    sigma = pm.Gamma('$\sigma$', 1, .7)
    y = pm.Normal('$y$', mu, sigma, observed=[7, 6, 5, 6, 6, 6.2, 5, 15])

# %%
mu
# Out:
# $\mu$

# %%
sigma
# Out:
# $\sigma$

# %%
y
# Out:
# $y$

# %% [markdown]
# ## Sampling

# %%
with model:
    prior = pm.sample_prior_predictive(1000)
    trace = pm.sample(1000)
    post = pm.sample_posterior_predictive(trace)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [$\sigma$, $\mu$]
# Sampling 4 chains: 100%|██████████| 6000/6000 [00:01<00:00, 5566.90draws/s]
# The acceptance probability does not match the target. It is 0.8958374536606624, but should be close to 0.8. Try to increase the number of tuning steps.
# 100%|██████████| 4000/4000 [00:01<00:00, 2290.93it/s]

# %%
import arviz as az

data = az.from_pymc3(trace=trace,
                     prior=prior,
                     posterior_predictive=post)
dataa = data
type(data)
# Out:
# arviz.data.inference_data.InferenceData

# %%
az.plot_trace(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5c8a89b898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5c89fa8f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5c89f5b518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5c89f0a828>]],
#       dtype=object)

# %%
data
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> posterior_predictive
# 	> prior
# 	> observed_data

# %%
# !git pull
from gempy.bayesian import plot_posterior as pp
import matplotlib.colors as colors

import seaborn as sns

# %%
pp.pal_disc.as_hex()
# Out:
# ['#90c1c6',
#  '#7eb1bc',
#  '#6ea0b1',
#  '#6090a7',
#  '#547d9a',
#  '#486b8b',
#  '#3e5a7c',
#  '#334769',
#  '#2a3656',
#  '#1f253f']

# %%
# %matplotlib notebook
from importlib import reload
reload(pp)
p = pp.PlotPosterior(dataa)
p.create_figure(figsize=(9,3), joyplot=True)
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
def change_iteration(iteration):
    p.plot_posterior(['$\mu$', '$\sigma$'], ['$\mu$', '$\sigma$'], '$y$', iteration)

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

interact(change_iteration, iteration=(0, 1000, 1))
# Out:
# interactive(children=(IntSlider(value=500, description='iteration', max=1000), Output()), _dom_classes=('widge…
# <function __main__.change_iteration(iteration)>

# %%
from gempy.bayesian.plot_posterior import my_cmap_full

# %%
az.plot_pair(data, divergences=True, var_names=['$\mu$', '$\sigma$', '$y$'], kind='hexbin', contour=True,
            colorbar=True, plot_kwargs={'cmap':my_cmap_full});
# Out:
# <img src="data:image/png;base64,..." width="1040">
